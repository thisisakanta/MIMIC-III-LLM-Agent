# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/
# Out:
#  20220708_152317.jpg
# '2023-11-07 Statement - USB Checking 7348.pdf'
#  2534868b36f74bbda0d0479c9f074d46.MOV
#  34043_COMBINED_6302_29042021.gdoc
# '4th year result.jpg'
#  73546835e2ac43ecb685f18ce393f6e4.MOV
# 'Applied AI Summit Topic.gdoc'
# 'Article 1.gdoc'
# 'Article 2.gdoc'
# 'Article 3.gdoc'
# 'Articles Summary.gdoc'
# 'Assignment 11.docx'
# 'B2 Visa Interview Questions (1).gdoc'
# 'B2 Visa Interview Questions.gdoc'
#  bq-results-20260307-234234-1772926980937
#  bq-results-20260307-234413-1772927084661
#  clinicalbert_results.txt
# 'Colab Notebooks'
# 'Copy of Copy of Copy of CSAI Week update V1.5- our interns.gslides'
# 'Copy of Copy of CSAI Week update V1.4- our interns.gslides'
# 'Copy of Copy of CSAI Week update V1.5- our interns.gslides'
# 'Copy of CSAI Week update V1.1- RWE.gslides'
# 'Copy of CSAI Week update V1.3- our interns.gslides'
# 'Copy of [Open] Applied AI Summit Speaker Slide Tempalte - 2025 v2.gslides'
# 'Copy of RWE Intern slide-1.9.gslides'
# 'Cover Letter.pdf'
# 'CSAI RWE template.gform'
# 'CSAI Week update V1.6- our interns.gslides'
#  CyberReceipt1608285063021.gdoc
# 'Disentangling Model Bias- Abstract.gdoc'
# 'endo4 yang2013.pdf'
# 'Expense Tracker .gsheet'
# 'Form I-983: 12-month self evaluation.gdoc'
# 'Getting started.pdf'
#  Gupta_Shraddha.jpeg
#  icu_llm_data
#  IMG_0006.HEIC
#  IMG_0007.HEIC
#  IMG_0010.HEIC
#  IMG_0011.HEIC
#  IMG_0012.HEIC
#  IMG_0014.HEIC
#  IMG_0015.HEIC
#  IMG_0016.HEIC
#  IMG_0035.HEIC
#  IMG_0036.HEIC
#  IMG_0037.HEIC
#  IMG_0038.HEIC
#  IMG_0039.HEIC
#  IMG_0040.HEIC
#  IMG_0043.heic
#  IMG_0044.heic
#  IMG_0045.HEIC
#  IMG_0051.HEIC
#  IMG_0058.HEIC
#  IMG_0060.HEIC
#  IMG_0062.HEIC
#  IMG_0063.HEIC
#  IMG_0064.HEIC
#  IMG_0065.HEIC
#  IMG_0066.HEIC
#  IMG_0067.HEIC
#  IMG_0068.HEIC
#  IMG_0069.HEIC
#  IMG_0070.HEIC
#  IMG_0071.HEIC
#  IMG_0072.HEIC
#  IMG_0073.HEIC
#  IMG_0074.HEIC
#  IMG_0075.HEIC
#  IMG_0076.HEIC
#  IMG_0077.HEIC
#  IMG_0078.HEIC
#  IMG_0079.HEIC
#  IMG_0092.MOV
#  IMG_0109.HEIC
#  IMG_0111.HEIC
#  IMG_0112.HEIC
#  IMG_0113.heic
#  IMG_0114.heic
#  IMG_0115.heic
#  IMG_0117.HEIC
#  IMG_0122.HEIC
#  IMG_0123.HEIC
#  IMG_0124.HEIC
#  IMG_0125.heic
#  IMG_0126.heic
#  IMG_0127.heic
#  IMG_0128.heic
#  IMG_0130.heic
#  IMG_20221110_214642_953.jpg
#  IMG_9834.heic
#  IMG_9835.heic
#  IMG_9836.heic
#  IMG_9837.MOV
#  IMG_9840.MOV
# 'Interview Prep.gdoc'
# 'Item list for new apartment.gdoc'
#  LLM_Embeddings_Healthcare_AI_Summit_SG.pptx
# 'Machine Learning_SG.gdoc'
#  mimic_clean_for_colab.zip
# 'NOC Jai Sai.gdoc'
#  OralBridge_JAMIA_Submission_Ready_Rebuilt.gdoc
# 'Passport first page.pdf'
#  PGRInsuranceIDCardAuto.pdf
# 'Publications List.gsheet'
# 'REVIEW OF LITERATURE.gdoc'
# 'ruchi thesis.gdoc'
# 'ruchi thesis.pdf'
#  RWE.gslides
# 'RWE Intern slide-1.8.gslides'
# 'RWE Intern Weekly Update  04 17 2021.gdoc'
# 'Scholarship at Northeastern University.gdoc'
#  Screenshot_20221217-031958_WhatsApp.jpg
# 'Sepsis in ICU patients- MIMIC IV.gdoc'
#  Shraddha_Gupta_Abstract.gdoc
# 'ShraddhaGupta Resume (1).gdoc'
# 'ShraddhaGupta Resume.gdoc'
# 'ShraddhaGupta Resume_v2_June6-21.gdoc'
# 'Social media sphere of CareStack.ai.gsheet'
# 'Social media sphere of CSAI.gsheet'
#  Tanmay.gdoc
# "Tanmay's Resume.gdoc"
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document.gdoc'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
#  visa.pdf
#  Wordbook.gsheet

# %%
# !ls /content/
# Out:
# drive  sample_data

# %%
# !ls /content/data/
# Out:
# ls: cannot access '/content/data/': No such file or directory

# %%
# !ls /content/data/in-hospital-mortality-cleaned/train | head
# Out:
# 10004_episode1_timeseries.csv
# 10007_episode1_timeseries.csv
# 1000_episode1_timeseries.csv
# 10013_episode1_timeseries.csv
# 10017_episode1_timeseries.csv
# 10027_episode1_timeseries.csv
# 10028_episode1_timeseries.csv
# 10029_episode1_timeseries.csv
# 10032_episode1_timeseries.csv
# 10038_episode1_timeseries.csv

# %%
# !find /content/data -name "*listfile*"

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device: Tesla T4

# %%
# !rm -rf /content/data

# %%
# !unzip "/content/drive/MyDrive/mimic_clean_for_colab.zip" -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/in-hospital-mortality-cleaned/train/71479_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/77625_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28065_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11342_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/82065_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18219_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/96259_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23014_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48523_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12899_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/96701_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54056_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31074_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18868_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90051_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10504_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/75526_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8422_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/580_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69776_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4260_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/87728_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/66892_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26125_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/89119_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12577_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11032_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/40442_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25345_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19698_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29222_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/41875_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/95160_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32615_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/60720_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18465_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17681_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/82619_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19277_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3969_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16093_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14227_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1522_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9388_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/47956_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22351_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15246_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24401_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/43697_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2488_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7391_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/66603_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8096_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28866_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/92651_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25836_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12921_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17739_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4413_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/43450_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67910_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69620_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9443_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/86749_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28084_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27260_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5824_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/71998_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27049_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28588_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28721_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21530_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/45300_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20322_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93788_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2966_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17810_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20907_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30015_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90676_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85258_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10906_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76644_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69797_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24771_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13666_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90795_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5993_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24692_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12074_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/46611_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16590_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27472_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1652_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17382_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/47003_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/49632_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/80369_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16072_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16757_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/79288_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11319_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/41098_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29866_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2033_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30365_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/89817_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17145_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23517_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11615_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26702_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/91465_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30669_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31198_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/91965_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9016_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1199_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10007_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/40386_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59009_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12896_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/65312_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25634_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/84938_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1409_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23468_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/52676_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9886_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29076_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6047_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11689_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14190_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25338_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1105_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1620_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/56854_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5060_episode7_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/77129_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32686_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30432_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48777_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16000_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15545_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/86662_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23986_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3176_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59877_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5626_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7492_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13830_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63619_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8676_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27647_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/75772_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10750_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4034_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/70188_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/74160_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69207_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26055_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/83594_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18353_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85373_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22406_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/41678_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18541_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/44082_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28018_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30466_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31397_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50651_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7525_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5791_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/82231_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25544_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/77471_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9030_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13864_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4183_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98518_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13033_episode8_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13241_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10704_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27537_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12694_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10420_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63569_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5556_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/52622_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4961_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69177_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11232_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13086_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26900_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4344_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11817_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2414_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18786_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72540_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/45457_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25949_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/96625_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/94491_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90479_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16370_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29048_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85531_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24018_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32173_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/70954_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/46474_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67408_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/89956_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/46178_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12834_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28973_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9672_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25306_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29544_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5030_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9791_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27375_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8344_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29660_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8961_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/305_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15498_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93391_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/64765_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17320_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15194_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11236_episode7_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31712_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/99283_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2990_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/69761_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25076_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5886_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12161_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14918_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28026_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90680_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24664_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76751_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/91092_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13033_episode13_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/897_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/45407_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6605_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32203_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22134_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98526_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76878_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29338_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19661_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/99334_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25708_episode8_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23726_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20263_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21892_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11829_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30855_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/66988_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/62345_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20528_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3734_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31462_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1580_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21259_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12983_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25894_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3238_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10112_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4676_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67150_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11700_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15278_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93571_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24616_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9993_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24133_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50434_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/52680_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/84208_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28771_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10482_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/77614_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27595_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/406_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50391_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25808_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17423_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14166_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3881_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22780_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/61856_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14085_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18724_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32554_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31910_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21002_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59347_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/61157_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6699_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/53759_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72725_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17707_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/45632_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29981_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26140_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2958_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72229_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3100_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/82293_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28293_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/61_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90310_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16419_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/66015_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10160_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23924_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/58501_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63992_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1945_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/84474_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32624_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24243_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76376_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29836_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6222_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24866_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93601_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/776_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67653_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/452_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26230_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25775_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24084_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4874_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/65620_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/75517_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21372_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16265_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11861_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63170_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32500_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31045_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17977_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72455_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2224_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1044_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/62762_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18693_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/73713_episode14_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23840_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14372_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/53669_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11588_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18530_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15560_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20643_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/90805_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15749_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1708_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27781_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/52494_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11866_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/88499_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4910_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4410_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12706_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5527_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/52653_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21216_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/49841_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/46080_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/44234_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/68218_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21833_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3277_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18614_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16924_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17513_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/81608_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30733_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26658_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98887_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/97046_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30388_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29722_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13140_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/89419_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23419_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12752_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1478_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14002_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/44383_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/56825_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23115_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19052_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/56200_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1174_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22707_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/57412_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98930_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63364_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22423_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21166_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1996_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48706_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18487_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/46836_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72641_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/58431_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11133_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2219_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4045_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/41897_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16258_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18068_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/68464_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25482_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25112_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50822_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/49188_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3078_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59979_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/88279_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/70469_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6761_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22050_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85725_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10814_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19705_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/86383_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/94525_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23642_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14755_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98685_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/72116_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22297_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2042_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30314_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31506_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12567_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/68916_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/42143_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10076_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27161_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/53466_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4712_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/634_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30618_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32605_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22320_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20194_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/47927_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23532_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16691_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19475_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/63088_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29420_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54358_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/65013_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27834_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/261_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76782_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/64601_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/55046_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2332_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20976_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11018_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14701_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15475_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13629_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18425_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/17722_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59281_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14267_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3929_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/99762_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/77019_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16053_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12537_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27694_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6253_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15179_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11191_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13325_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6876_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32359_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/42471_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/80326_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/78536_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/81534_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/55308_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/423_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9270_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19620_episode12_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12613_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/91603_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9855_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6094_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/30626_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20511_episode1_timeseries.csv
# ...
#   inflating: /content/data/in-hospital-mortality-cleaned/train/15122_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29239_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76479_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26432_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67375_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16088_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/75315_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12183_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/81881_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/86709_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6704_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48344_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/55023_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/60380_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20336_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/44506_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23790_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/94977_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/78934_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8245_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59948_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3049_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5215_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10446_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28090_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27851_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21447_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/62438_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93290_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7142_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4407_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7266_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25822_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12935_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/61259_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/65894_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/7843_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12310_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24995_episode4_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18827_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/95707_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/57050_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/58891_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/40729_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1050_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2515_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/62776_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20574_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4749_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/68368_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12299_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16554_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54073_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/75503_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/67480_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50597_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9215_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4860_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13187_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4245_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/92007_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23619_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/56229_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20979_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/43122_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13340_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85272_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21042_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19877_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54891_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28119_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14827_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1374_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/50879_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/94757_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/60878_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/65544_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10174_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19940_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10651_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/20308_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25411_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19823_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/58541_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14256_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14873_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48676_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31904_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10978_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/32664_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14990_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/43599_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/57562_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16800_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11788_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/95235_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1004_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59194_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/3895_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12622_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/76012_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18819_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/9987_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98769_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/64191_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/26603_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/96260_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25963_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1098_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/40287_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8020_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/29504_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25880_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/25225_episode6_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8209_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/48121_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27172_episode5_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/85492_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/21586_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1076_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/19675_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18184_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/59720_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/24959_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18067_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8921_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/57739_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/88309_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10222_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13767_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/92420_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/31998_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/6349_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/78708_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14792_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/16526_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/73504_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/49443_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54724_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/138_episode3_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/93689_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/55136_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/60295_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/4512_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/64771_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/8896_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/10635_episode12_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/11464_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/27944_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/78204_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/28185_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/86648_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/54228_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/13417_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/2589_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/57449_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12820_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/1423_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/56757_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/84912_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/12709_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/23442_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/14555_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/18317_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/98642_episode1_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/5528_episode2_timeseries.csv
#   inflating: /content/data/in-hospital-mortality-cleaned/train/22250_episode1_timeseries.csv

# %%
# !ls /content/data/in-hospital-mortality
# !ls /content/data/in-hospital-mortality-cleaned/train | head
# Out:
# test  test_listfile.csv  train	train_listfile.csv  val_listfile.csv
# 10004_episode1_timeseries.csv
# 10007_episode1_timeseries.csv
# 1000_episode1_timeseries.csv
# 10013_episode1_timeseries.csv
# 10017_episode1_timeseries.csv
# 10027_episode1_timeseries.csv
# 10028_episode1_timeseries.csv
# 10029_episode1_timeseries.csv
# 10032_episode1_timeseries.csv
# 10038_episode1_timeseries.csv

# %%
# !pip install mamba-ssm
# !pip install einops
# !pip install scikit-learn
# Out:
# Collecting mamba-ssm
#   Downloading mamba_ssm-2.3.0.tar.gz (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (2.10.0+cu128)
# Requirement already satisfied: triton in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (3.6.0)
# Collecting ninja (from mamba-ssm)
#   Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (0.8.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (5.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (26.0)
# Requirement already satisfied: setuptools>=61.0.0 in /usr/local/lib/python3.12/dist-packages (from mamba-ssm) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->mamba-ssm) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->mamba-ssm) (1.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (1.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->mamba-ssm) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (0.24.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->mamba-ssm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->mamba-ssm) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers->mamba-ssm) (0.1.2)
# Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# Building wheels for collected packages: mamba-ssm
#   Building wheel for mamba-ssm (pyproject.toml) ... canceled
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 423, in run
#     _, build_failures = build(
#                         ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/wheel_builder.py", line 319, in build
#     wheel_file = _build_one(
#                  ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/wheel_builder.py", line 193, in _build_one
#     wheel_path = _build_one_inside_env(
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/wheel_builder.py", line 233, in _build_one_inside_env
#     wheel_path = build_wheel_pep517(
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/build/wheel.py", line 30, in build_wheel_pep517
#     wheel_name = backend.build_wheel(
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/misc.py", line 682, in build_wheel
#     return super().build_wheel(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pyproject_hooks/_impl.py", line 209, in build_wheel
#     return self._call_hook('build_wheel', {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/pyproject_hooks/_impl.py", line 311, in _call_hook
#     self._subprocess_runner(
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/subprocess.py", line 237, in runner
#     call_subprocess(
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/subprocess.py", line 151, in call_subprocess
#     line: str = proc.stdout.readline()
#                 ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.12/logging/__init__.py", line 1586, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1684, in _log
#     self.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1028, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/console.py", line 1673, in print
#     with self:
#          ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "/usr/local/lib/python3.12/dist-packages/pip/_vendor/rich/console.py", line 2060, in _check_buffer
#     self.file.write(text)
# KeyboardInterrupt
# ^C
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import torch
from mamba_ssm import Mamba

print("CUDA:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_174/2888881433.py in <cell line: 0>()
#       1 import torch
# ----> 2 from mamba_ssm import Mamba
#       3
#       4 print("CUDA:", torch.cuda.is_available())
#       5 print("Device:", torch.cuda.get_device_name(0))
#
# ModuleNotFoundError: No module named 'mamba_ssm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install transformers peft scikit-learn accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.24.3)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.10.0+cu128)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

CLEAN_DIR = "/content/data/in-hospital-mortality-cleaned"
RAW_DIR = "/content/data/in-hospital-mortality"
DRIVE_SAVE_DIR = "/content/drive/MyDrive/icu_llm_data"

os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)

MAX_HOURS = 48

# %%
def build_text_from_timeseries(df):
    df = df[df["Hours"] <= MAX_HOURS]

    summary = ["ICU Stay Summary (First 48 Hours):"]

    for col in df.columns:
        if col == "Hours":
            continue

        values = df[col].dropna()
        if len(values) == 0:
            continue

        mean = values.mean()
        std = values.std()
        last = values.iloc[-1]

        summary.append(
            f"{col}: mean {mean:.2f}, standard deviation {std:.2f}, "
            f"last recorded value {last:.2f}."
        )

    return " ".join(summary)

# %%
def build_split(split):
    listfile = pd.read_csv(f"{RAW_DIR}/{split}_listfile.csv")
    folder = "train" if split == "val" else split

    texts = []
    labels = []

    for _, row in tqdm(listfile.iterrows(), total=len(listfile)):
        fname = row["stay"]
        label = row["y_true"]

        path = Path(f"{CLEAN_DIR}/{folder}/{fname}")
        df = pd.read_csv(path)

        text = build_text_from_timeseries(df)

        texts.append(text)
        labels.append(label)

    df_out = pd.DataFrame({"text": texts, "label": labels})
    df_out.to_csv(f"{DRIVE_SAVE_DIR}/{split}_text.csv", index=False)

    return df_out

# %%
train_df = build_split("train")
val_df   = build_split("val")
test_df  = build_split("test")

print("Done.")
print("Example text length:", len(train_df["text"][0]))
# Out:
# 100%|██████████| 14681/14681 [01:03<00:00, 229.82it/s]
# 100%|██████████| 3222/3222 [00:14<00:00, 224.84it/s]
# 100%|██████████| 3236/3236 [00:14<00:00, 230.47it/s]
# Done.
# Example text length: 1216

# %%
train_df["text"][0][:500]
# Out:
# 'ICU Stay Summary (First 48 Hours): Diastolic blood pressure: mean 43.98, standard deviation 4.93, last recorded value 50.00. Fraction inspired oxygen: mean 0.44, standard deviation 0.05, last recorded value 0.50. Glascow coma scale eye opening: mean 3.83, standard deviation 0.39, last recorded value 4.00. Glascow coma scale motor response: mean 6.00, standard deviation 0.00, last recorded value 6.00. Glascow coma scale verbal response: mean 5.00, standard deviation 0.00, last recorded value 5.00'

# %%
train_df["text"].str.len().describe()
# Out:
# count    14681.000000
# mean      1161.579593
# std        120.522685
# min        107.000000
# 25%       1137.000000
# 50%       1186.000000
# 75%       1213.000000
# max       1388.000000
# Name: text, dtype: float64

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=1
)

model.to(device)

print("Model loaded.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_172/718904898.py in <cell line: 0>()
#       1 import torch
# ----> 2 from transformers import AutoTokenizer, AutoModelForSequenceClassification
#       3
#       4 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       5 print("Device:", device)
#
# /usr/local/lib/python3.12/dist-packages/transformers/__init__.py in <module>
#      28
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.12/dist-packages/transformers/dependency_versions_check.py in <module>
#      14
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      17
#      18
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/__init__.py in <module>
#      20
#      21 from .. import __version__
# ---> 22 from .auto_docstring import (
#      23     ClassAttrs,
#      24     ClassDocstring,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/auto_docstring.py in <module>
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      31
#      32
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in <module>
#      45     from torch.types import _dtype
#      46
# ---> 47     from ..model_debugging_utils import model_addition_debugger_context
#      48
#      49     _is_torch_available = True
#
# /usr/local/lib/python3.12/dist-packages/transformers/model_debugging_utils.py in <module>
#      32     # Note to code inspectors: this toolbox is intended for people who add models to `transformers`.
#      33     if torch.distributed.is_available():
# ---> 34         import torch.distributed.tensor
#      35
#      36         _torch_distributed_available = True
#
# /usr/local/lib/python3.12/dist-packages/torch/distributed/tensor/__init__.py in <module>
#       2
#       3 import torch
# ----> 4 import torch.distributed.tensor._ops  # force import all built-in dtensor ops
#       5 from torch.distributed.device_mesh import DeviceMesh, init_device_mesh  # noqa: F401
#       6 from torch.distributed.tensor._api import (
#
# /usr/local/lib/python3.12/dist-packages/torch/distributed/tensor/_ops/__init__.py in <module>
#       6 from ._pointwise_ops import *  # noqa: F403
#       7 from ._random_ops import *  # noqa: F403
# ----> 8 from ._tensor_ops import *  # noqa: F403
#       9 from ._view_ops import *  # noqa: F403
#
# /usr/local/lib/python3.12/dist-packages/torch/distributed/tensor/_ops/_tensor_ops.py in <module>
#      39     Shard,
#      40 )
# ---> 41 from torch.fx.experimental.symbolic_shapes import statically_known_true
#      42
#      43
#
# /usr/local/lib/python3.12/dist-packages/torch/fx/experimental/symbolic_shapes.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 import sympy
#       4 from sympy import S
#       5
#
# /usr/local/lib/python3.12/dist-packages/sympy/__init__.py in <module>
#     161         intersecting_product)
#     162
# --> 163 from .simplify import (simplify, hypersimp, hypersimilar, logcombine,
#     164         separatevars, posify, besselsimp, kroneckersimp, signsimp,
#     165         nsimplify, FU, fu, sqrtdenest, cse, epath, EPath, hyperexpand,
#
# /usr/local/lib/python3.12/dist-packages/sympy/simplify/__init__.py in <module>
#       5 the expression (x+x)**2 will be converted into 4*x**2
#       6 """
# ----> 7 from .simplify import (simplify, hypersimp, hypersimilar,
#       8     logcombine, separatevars, posify, besselsimp, kroneckersimp,
#       9     signsimp, nsimplify)
#
# /usr/local/lib/python3.12/dist-packages/sympy/simplify/simplify.py in <module>
#      39 from sympy.polys.numberfields.minpoly import _is_sum_surds, _minimal_polynomial_sq
#      40 from sympy.sets.sets import Set
# ---> 41 from sympy.simplify.combsimp import combsimp
#      42 from sympy.simplify.cse_opts import sub_pre, sub_post
#      43 from sympy.simplify.hyperexpand import hyperexpand
#
# /usr/local/lib/python3.12/dist-packages/sympy/simplify/combsimp.py in <module>
#       4 from sympy.functions.combinatorial.factorials import binomial, factorial
#       5 from sympy.functions import gamma
# ----> 6 from sympy.simplify.gammasimp import gammasimp, _gammasimp
#       7
#       8 from sympy.utilities.timeutils import timethis
#
# KeyboardInterrupt:

# %%
from torch.utils.data import Dataset

MAX_LENGTH = 512

class ICUTextDataset(Dataset):
    def __init__(self, df):
        self.texts = df["text"].tolist()
        self.labels = df["label"].tolist()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        encoding = tokenizer(
            self.texts[idx],
            padding="max_length",
            truncation=True,
            max_length=MAX_LENGTH,
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(),
            "attention_mask": encoding["attention_mask"].squeeze(),
            "labels": torch.tensor(self.labels[idx], dtype=torch.float)
        }

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 8

train_dataset = ICUTextDataset(train_df)
val_dataset   = ICUTextDataset(val_df)
test_dataset  = ICUTextDataset(test_df)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE)

print("DataLoaders ready.")
# Out:
# DataLoaders ready.

# %%
import torch.nn as nn
from sklearn.metrics import roc_auc_score, average_precision_score

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)

# ---- CLASS IMBALANCE FIX ----
pos = train_df["label"].sum()
neg = len(train_df) - pos
pos_weight = torch.tensor([neg / pos]).to(device)
print("Positive weight:", pos_weight)

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

EPOCHS = 3
# Out:
# Positive weight: tensor([6.3885], device='cuda:0', dtype=torch.float64)

# %%
for epoch in range(EPOCHS):
    model.train()
    total_loss = 0

    for batch in train_loader:
        optimizer.zero_grad()

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        logits = outputs.logits.view(-1)

        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1} Train Loss:", total_loss / len(train_loader))

    # Validation
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )

            logits = outputs.logits.view(-1)
            probs = torch.sigmoid(logits)

            all_preds.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    roc = roc_auc_score(all_labels, all_preds)
    pr  = average_precision_score(all_labels, all_preds)

    print(f"Validation ROC-AUC: {roc:.4f}")
    print(f"Validation PR-AUC:  {pr:.4f}")
# Out:
# Epoch 1 Train Loss: 1.0176049701723398
# Validation ROC-AUC: 0.7767
# Validation PR-AUC:  0.3789
# Epoch 2 Train Loss: 1.1096232954031242
# Validation ROC-AUC: 0.7710
# Validation PR-AUC:  0.3546

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for batch in test_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        logits = outputs.logits.squeeze()
        probs = torch.sigmoid(logits)

        all_preds.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

roc = roc_auc_score(all_labels, all_preds)
pr  = average_precision_score(all_labels, all_preds)

print("Test ROC-AUC:", roc)
print("Test PR-AUC:", pr)
# Out:
# Test ROC-AUC: 0.7821859923691223
# Test PR-AUC: 0.32329134445462354

# %%
# %%writefile clinicalbert_results.txt
# Model: ClinicalBERT
# Representation: mean + std + last
# LR: 2e-5
# Batch size: 8
# Epochs: 3
#
# Val ROC: 0.7767
# Val PR: 0.3789
# Test ROC: 0.782
# Test PR: 0.323
# Out:
# Writing clinicalbert_results.txt

# %%
# !mv clinicalbert_results.txt /content/drive/MyDrive/

# %% [markdown]
# ###----------TRANSFORMER ------

# %%
# !pip install scikit-learn tqdm
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import roc_auc_score, average_precision_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

CLEAN_DIR = "/content/data/in-hospital-mortality-cleaned"
RAW_DIR = "/content/data/in-hospital-mortality"
MAX_HOURS = 48
# Out:
# Device: cpu

# %%
def infer_feature_columns():
    sample = next(Path(CLEAN_DIR + "/train").glob("*_timeseries.csv"))
    df = pd.read_csv(sample)
    return sorted([c for c in df.columns if c != "Hours"])

feature_cols = infer_feature_columns()
print("Number of features:", len(feature_cols))
# Out:
# Number of features: 17

# %%
def resample_hourly(df, feature_cols):
    df = df.sort_values("Hours")
    df["Hour_int"] = df["Hours"].astype(int)
    df = df[df["Hour_int"] < MAX_HOURS]
    df = df.groupby("Hour_int")[feature_cols].mean()
    df = df.reindex(range(MAX_HOURS))
    return df.to_numpy(dtype=np.float32)

# %%
class IHMDataset(Dataset):
    def __init__(self, split, feature_cols, mean=None, std=None):
        self.feature_cols = feature_cols
        self.mean = mean
        self.std = std

        listfile = pd.read_csv(f"{RAW_DIR}/{split}_listfile.csv")
        folder = "train" if split == "val" else split

        self.X = []
        self.y = []

        for _, row in tqdm(listfile.iterrows(), total=len(listfile)):
            fname = row["stay"]
            label = row["y_true"]

            path = Path(f"{CLEAN_DIR}/{folder}/{fname}")
            df = pd.read_csv(path)

            X = resample_hourly(df, feature_cols)

            self.X.append(X)
            self.y.append(label)

        self.X = np.stack(self.X)
        self.y = np.array(self.y)

        if mean is not None:
            self.X = (self.X - mean) / (std + 1e-6)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
            x = self.X[idx]
            x = np.nan_to_num(x)
            return (
                torch.tensor(x, dtype=torch.float32),
                torch.tensor(self.y[idx], dtype=torch.float32)
            )

# %%
train_raw = IHMDataset("train", feature_cols)
train_data = train_raw.X

mean = np.nanmean(train_data, axis=(0,1))
std  = np.nanstd(train_data, axis=(0,1))

train_dataset = IHMDataset("train", feature_cols, mean, std)
val_dataset   = IHMDataset("val", feature_cols, mean, std)
test_dataset  = IHMDataset("test", feature_cols, mean, std)
# Out:
# 100%|██████████| 14681/14681 [01:43<00:00, 141.86it/s]
# 100%|██████████| 14681/14681 [01:22<00:00, 177.14it/s]
# 100%|██████████| 3222/3222 [00:17<00:00, 188.27it/s]
# 100%|██████████| 3236/3236 [00:17<00:00, 187.19it/s]

# %%
BATCH_SIZE = 64

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
class TimeSeriesTransformer(nn.Module):
    def __init__(self, input_dim, d_model=128, nhead=4, num_layers=3, dropout=0.2):
        super().__init__()

        self.input_proj = nn.Linear(input_dim, d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=256,
            dropout=dropout,
            batch_first=True
        )

        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Sequential(
            nn.Linear(d_model, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        x = self.input_proj(x)
        x = self.transformer(x)
        x = x.mean(dim=1)  # mean pooling over time
        logits = self.classifier(x)
        return logits

# %%
# Fix for sympy/torch incompatibility: Uninstall current sympy and install a compatible version.
# *** A Colab runtime restart is required after running this cell once for the changes to take effect. ***
#!pip install sympy==1.12

import torch.nn as nn

model = TimeSeriesTransformer(input_dim=len(feature_cols)).to(device)

pos = train_dataset.y.sum()
neg = len(train_dataset) - pos
pos_weight = torch.tensor([neg / pos]).to(device)

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
EPOCHS = 15

# %%
for epoch in range(EPOCHS):
    model.train()
    total_loss = 0

    for x, y in train_loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x).view(-1)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    model.eval()
    preds = []
    labels = []

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            logits = model(x).view(-1)
            probs = torch.sigmoid(logits)

            preds.extend(probs.cpu().numpy())
            labels.extend(y.numpy())

    roc = roc_auc_score(labels, preds)
    pr = average_precision_score(labels, preds)

    print(f"Epoch {epoch+1} | Loss {total_loss/len(train_loader):.4f} | ROC {roc:.4f} | PR {pr:.4f}")
# Out:
# Epoch 1 | Loss 1.0040 | ROC 0.8128 | PR 0.4363
# Epoch 2 | Loss 0.9478 | ROC 0.8245 | PR 0.4452
# Epoch 3 | Loss 0.9300 | ROC 0.8183 | PR 0.4215
# Epoch 4 | Loss 0.9286 | ROC 0.8257 | PR 0.4601
# Epoch 5 | Loss 0.9064 | ROC 0.8186 | PR 0.4547
# Epoch 6 | Loss 0.9202 | ROC 0.8109 | PR 0.4340
# Epoch 7 | Loss 0.9052 | ROC 0.8200 | PR 0.4461
# Epoch 8 | Loss 0.9004 | ROC 0.8209 | PR 0.4471
# Epoch 9 | Loss 0.9007 | ROC 0.8134 | PR 0.4373
# Epoch 10 | Loss 0.9200 | ROC 0.8244 | PR 0.4439
# Epoch 11 | Loss 0.9152 | ROC 0.8237 | PR 0.4585
# Epoch 12 | Loss 0.8993 | ROC 0.8200 | PR 0.4611
# Epoch 13 | Loss 0.9066 | ROC 0.8194 | PR 0.4483
# Epoch 14 | Loss 0.9071 | ROC 0.8019 | PR 0.3743
# Epoch 15 | Loss 0.9168 | ROC 0.7997 | PR 0.3927

# %%
model.eval()
preds = []
labels = []

with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        logits = model(x)
        probs = torch.sigmoid(logits)

        preds.extend(probs.cpu().numpy())
        labels.extend(y.numpy())

print("Test ROC:", roc_auc_score(labels, preds))
print("Test PR:", average_precision_score(labels, preds))
# Out:
# Test ROC: 0.8082769986210608
# Test PR: 0.3237020071229633

# %% [markdown]
# #---------SHAP--------

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.3)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import shap

class TransformerWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        # x: [N, D]
        # Expand back to [N, 48, D]
        x = x.unsqueeze(1).repeat(1, 48, 1)
        return torch.sigmoid(self.model(x))

# %%
background = []

for i in range(100):
    x, _ = train_dataset[i]
    background.append(x.mean(dim=0).numpy())

background = np.array(background)

# %%
X_explain = []
for i in range(200):
    x, _ = test_dataset[i]
    X_explain.append(x.mean(dim=0).numpy())

X_explain = np.array(X_explain)

# %%
wrapper = TransformerWrapper(model).to(device)
wrapper.eval()

explainer = shap.DeepExplainer(wrapper, torch.tensor(background).to(device))

shap_values = explainer.shap_values(torch.tensor(X_explain).to(device))

# %%
shap.summary_plot(
    shap_values[0],
    X_explain,
    feature_names=feature_cols
)

# %% [markdown]
# ClincalBert- Freeze base and train one one head

# %%
# !pip install -q transformers scikit-learn

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np

from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import roc_auc_score, average_precision_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
#load model
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=1
)

model.to(device)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: emilyalsentzer/Bio_ClinicalBERT
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
#load data files
import pandas as pd

BASE_PATH = "/content/drive/MyDrive/icu_llm_data"

train_df = pd.read_csv(f"{BASE_PATH}/train_text.csv")
val_df   = pd.read_csv(f"{BASE_PATH}/val_text.csv")
test_df  = pd.read_csv(f"{BASE_PATH}/test_text.csv")

print(train_df.head())
print(train_df.columns)
# Out:
#                                                 text  label
# 0  ICU Stay Summary (First 48 Hours): Diastolic b...      0
# 1  ICU Stay Summary (First 48 Hours): Diastolic b...      0
# 2  ICU Stay Summary (First 48 Hours): Diastolic b...      0
# 3  ICU Stay Summary (First 48 Hours): Diastolic b...      0
# 4  ICU Stay Summary (First 48 Hours): Diastolic b...      0
# Index(['text', 'label'], dtype='object')

# %%
#load dataset class
import torch
from torch.utils.data import Dataset, DataLoader

class IHMTextDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.texts = dataframe["text"].tolist()
        self.labels = dataframe["label"].tolist()   # <-- FIXED
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(),
            "attention_mask": encoding["attention_mask"].squeeze(),
            "labels": torch.tensor(self.labels[idx], dtype=torch.float)
        }

# %%
#recreate dataloaders
BATCH_SIZE = 16

train_dataset = IHMTextDataset(train_df, tokenizer)
val_dataset   = IHMTextDataset(val_df, tokenizer)
test_dataset  = IHMTextDataset(test_df, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
#load model
from transformers import AutoModel
import torch.nn as nn
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"

bert = AutoModel.from_pretrained(MODEL_NAME)

# Freeze all backbone layers
for param in bert.parameters():
    param.requires_grad = False
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: emilyalsentzer/Bio_ClinicalBERT
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#add classification head
class FrozenBERTClassifier(nn.Module):
    def __init__(self, bert_model):
        super().__init__()
        self.bert = bert_model
        self.classifier = nn.Linear(self.bert.config.hidden_size, 1)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        cls_embedding = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_embedding)
        return logits.squeeze(-1)

model = FrozenBERTClassifier(bert)
model.to(device)
# Out:
# FrozenBERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
#optimizer
optimizer = torch.optim.AdamW(model.classifier.parameters(), lr=2e-4)
criterion = nn.BCEWithLogitsLoss()

# %%
#training loop
from sklearn.metrics import roc_auc_score, average_precision_score
import numpy as np

EPOCHS = 5

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0

    for batch in train_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        logits = model(input_ids, attention_mask)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1} | Train Loss: {total_loss / len(train_loader)}")

    # Validation
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            logits = model(input_ids, attention_mask)
            probs = torch.sigmoid(logits)

            all_preds.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    roc = roc_auc_score(all_labels, all_preds)
    pr  = average_precision_score(all_labels, all_preds)

    print(f"Validation ROC-AUC: {roc:.4f}")
    print(f"Validation PR-AUC:  {pr:.4f}")
# Out:
# Epoch 1 | Train Loss: 0.4019868078850583
# Validation ROC-AUC: 0.5938
# Validation PR-AUC:  0.1868

# %% [markdown]
# unfreeze last 2 layers and train classifier while keeping rest of the bert frozen

# %%
#mount drive, install transformaer, load data steps already completed by re-running above codes
#load tokenizer
from transformers import AutoTokenizer

MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
#recreate dataset class
import torch
from torch.utils.data import Dataset, DataLoader

class IHMTextDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.texts = dataframe["text"].tolist()
        self.labels = dataframe["label"].tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt"
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(),
            "attention_mask": encoding["attention_mask"].squeeze(),
            "labels": torch.tensor(self.labels[idx], dtype=torch.float)
        }

# %%
#recreate data loaders
BATCH_SIZE = 16

train_loader = DataLoader(IHMTextDataset(train_df, tokenizer), batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(IHMTextDataset(val_df, tokenizer), batch_size=BATCH_SIZE)
test_loader  = DataLoader(IHMTextDataset(test_df, tokenizer), batch_size=BATCH_SIZE)

# %%
#load bioclinicalBERT again
from transformers import AutoModel
import torch.nn as nn
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

bert = AutoModel.from_pretrained(MODEL_NAME)
# Out:
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: emilyalsentzer/Bio_ClinicalBERT
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#freeze all layers first
for param in bert.parameters():
    param.requires_grad = False

# %%
#unfreeze last 2 encoder layers
# BioClinicalBERT has 12 layers: 0–11
for param in bert.encoder.layer[-2:].parameters():
    param.requires_grad = True

# %%
# Also unfreeze pooler if present
if hasattr(bert, "pooler"):
    for param in bert.pooler.parameters():
        param.requires_grad = True

# %%
#add classification head
class PartialFrozenBERT(nn.Module):
    def __init__(self, bert_model):
        super().__init__()
        self.bert = bert_model
        self.classifier = nn.Linear(self.bert.config.hidden_size, 1)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        cls_embedding = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_embedding)
        return logits.squeeze(-1)

model = PartialFrozenBERT(bert)
model.to(device)
# Out:
# PartialFrozenBERT(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
# )

# %%
#optimizer only trainable parameters
optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=2e-5   # lower LR since we are tuning BERT layers
)

criterion = nn.BCEWithLogitsLoss()

# %%
#training loop
from sklearn.metrics import roc_auc_score, average_precision_score
import numpy as np

EPOCHS = 5

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0

    for batch in train_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        logits = model(input_ids, attention_mask)
        loss = criterion(logits, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1} | Train Loss: {total_loss / len(train_loader)}")

    # Validation
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            logits = model(input_ids, attention_mask)
            probs = torch.sigmoid(logits)

            all_preds.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    roc = roc_auc_score(all_labels, all_preds)
    pr  = average_precision_score(all_labels, all_preds)

    print(f"Validation ROC-AUC: {roc:.4f}")
    print(f"Validation PR-AUC:  {pr:.4f}")
# Out:
# Epoch 1 | Train Loss: 0.3638628110825236
# Validation ROC-AUC: 0.8026
# Validation PR-AUC:  0.4130
# Epoch 2 | Train Loss: 0.32424325249228864
# Validation ROC-AUC: 0.8273
# Validation PR-AUC:  0.4431
# Epoch 3 | Train Loss: 0.3148724888583284
# Validation ROC-AUC: 0.8318
# Validation PR-AUC:  0.4604
# Epoch 4 | Train Loss: 0.3066931704631428
# Validation ROC-AUC: 0.8358
# Validation PR-AUC:  0.4842
# Epoch 5 | Train Loss: 0.3019477733145093
# Validation ROC-AUC: 0.8338
# Validation PR-AUC:  0.4805

# %%
#evaluate on test set
model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for batch in test_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        logits = model(input_ids, attention_mask)
        probs = torch.sigmoid(logits)

        all_preds.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

from sklearn.metrics import roc_auc_score, average_precision_score

print("Test ROC:", roc_auc_score(all_labels, all_preds))
print("Test PR :", average_precision_score(all_labels, all_preds))
# Out:
# Test ROC: 0.8460941266157692
# Test PR : 0.4417161098004961

# %% [markdown]
# Difficult vs easy cases approach using XGBoost

# %%
#intsall libraries
# !pip install xgboost scikit-learn pandas numpy
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#import libraries
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, average_precision_score

import xgboost as xgb

# %%
#load feature data
DATA_PATH = "/content/drive/MyDrive/in-hospital-mortality-7subseq-features/"

train_df = pd.read_csv(DATA_PATH + "train_features.csv")
val_df   = pd.read_csv(DATA_PATH + "val_features.csv")
test_df  = pd.read_csv(DATA_PATH + "test_features.csv")

print(train_df.shape)
print(val_df.shape)
print(test_df.shape)
# Out:
# (14681, 834)
# (3222, 834)
# (3236, 834)

# %%
#spot check to ensure feature columns match across splits
print((train_df.columns == val_df.columns).all())
print((train_df.columns == test_df.columns).all())
# Out:
# True
# True

# %%
#separate features and labels
X_train = train_df.drop(columns=["label"])
y_train = train_df["label"]

X_val = val_df.drop(columns=["label"])
y_val = val_df["label"]

X_test = test_df.drop(columns=["label"])
y_test = test_df["label"]

# %%
print(type(X_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Mean imputation
imputer = SimpleImputer(strategy="mean")

X_train = imputer.fit_transform(X_train)
X_val   = imputer.transform(X_val)
X_test  = imputer.transform(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Height_full_skew' 'Height_first10_skew' 'Height_first25_skew'
#  'Height_first50_skew' 'Height_last50_skew' 'Height_last25_skew'
#  'Height_last10_skew']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Height_full_skew' 'Height_first10_skew' 'Height_first25_skew'
#  'Height_first50_skew' 'Height_last50_skew' 'Height_last25_skew'
#  'Height_last10_skew']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Height_full_skew' 'Height_first10_skew' 'Height_first25_skew'
#  'Height_first50_skew' 'Height_last50_skew' 'Height_last25_skew'
#  'Height_last10_skew']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
np.isnan(X_train).sum().sum()
# Out:
# np.int64(0)

# %%
#train XGBoost
from xgboost import XGBClassifier

model = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss",
    tree_method="hist"
)

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
#evaluation on validation set
val_probs = model.predict_proba(X_val)[:,1]

print("Validation ROC:", roc_auc_score(y_val, val_probs))
print("Validation PR:", average_precision_score(y_val, val_probs))
# Out:
# Validation ROC: 0.8638926941391097
# Validation PR: 0.5663751635113423

# %%
#evaluation on test set
test_probs = model.predict_proba(X_test)[:,1]

print("Test ROC:", roc_auc_score(y_test, test_probs))
print("Test PR:", average_precision_score(y_test, test_probs))
# Out:
# Test ROC: 0.8630206990362373
# Test PR: 0.5224254465486005

# %%
#training predictions
train_probs = model.predict_proba(X_train)[:,1]

train_preds = (train_probs >= 0.5).astype(int)

train_results = pd.DataFrame({
    "label": y_train,
    "prob": train_probs,
    "pred": train_preds
})

train_results["correct"] = (train_results["label"] == train_results["pred"]).astype(int)

train_results["correct"].value_counts()
# Out:
# correct
# 1    14672
# 0        9
# Name: count, dtype: int64

# %%
#save xgboost training predictions result
train_results.to_csv(
    "/content/drive/MyDrive/in-hospital-mortality-7subseq-features/xgb_train_predictions1.csv",
    index=False
)

# %%
#scaling only for LR
scaler = StandardScaler()

X_train_lr = scaler.fit_transform(X_train)
X_val_lr   = scaler.transform(X_val)
X_test_lr  = scaler.transform(X_test)

# %%
#train logistic regression baseline on validation set
#since our training accuracy was 14657 correct and 24 incorrect
#that means our model has memorised the training set
#so use out-of-sample predictions (validation set)
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(
    max_iter=2000,
    class_weight="balanced",
    n_jobs=-1
)

lr_model.fit(X_train_lr, y_train)

lr_val_probs = lr_model.predict_proba(X_val_lr)[:,1]
lr_val_preds = (lr_val_probs >= 0.5).astype(int)

# %%
#train random forest baseline
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    n_jobs=-1,
    class_weight="balanced"
)

rf_model.fit(X_train, y_train)

rf_val_probs = rf_model.predict_proba(X_val)[:,1]
rf_val_preds = (rf_val_probs >= 0.5).astype(int)

# %%
#use xgboost validation predictions
xgb_val_probs = model.predict_proba(X_val)[:,1]
xgb_val_preds = (xgb_val_probs >= 0.5).astype(int)

# %%
#combine predictions
val_results = pd.DataFrame({
    "label": y_val,

    "lr_pred": lr_val_preds,
    "rf_pred": rf_val_preds,
    "xgb_pred": xgb_val_preds
})

# %%
#determine correctness per model
val_results["lr_correct"] = (val_results["lr_pred"] == val_results["label"])
val_results["rf_correct"] = (val_results["rf_pred"] == val_results["label"])
val_results["xgb_correct"] = (val_results["xgb_pred"] == val_results["label"])

# %%
#compute misclassification count
val_results["num_models_wrong"] = (
    (~val_results["lr_correct"]).astype(int) +
    (~val_results["rf_correct"]).astype(int) +
    (~val_results["xgb_correct"]).astype(int)
)

#Now each patient has-
#0 → all models correct
#1 → one model wrong
#2 → two models wrong
#3 → all models wrong

# %%
#define difficulty
#easy case- num_models_wrong <= 1
#difficult case - num_models_wrong >= 2
val_results["difficulty"] = val_results["num_models_wrong"].apply(
    lambda x: "difficult" if x >= 2 else "easy"
)

# %%
# check distribution
val_results["difficulty"].value_counts()
# Out:
# difficulty
# easy         2862
# difficult     360
# Name: count, dtype: int64

# %% [markdown]
# Validation sample- 3222
# easy cases- 2862/3222 =. 88.8%
# difficult cases- 360/3222 = 11.1%

# %%
#save difficulty labels
val_results.to_csv(
    "/content/drive/MyDrive/in-hospital-mortality-7subseq-features/validation_difficulty_labels1.csv",
    index=False
)

# %% [markdown]
# Near-perfect training accuracy suggests:833 statistical features are extremely expressive
#
# Which is good for modeling but makes training-based difficulty detection unreliable, hence the validation-based approach.

# %%
#visualizing difficulty distribution
val_results["num_models_wrong"].value_counts()
# Out:
# num_models_wrong
# 0    2270
# 1     592
# 2     220
# 3     140
# Name: count, dtype: int64

# %% [markdown]
# 140 ICU cases are the hardest

# %%
#motality rate by difficulty
val_results.groupby("num_models_wrong")["label"].mean()
# Out:
# num_models_wrong
# 0    0.026432
# 1    0.158784
# 2    0.731818
# 3    0.864286
# Name: label, dtype: float64

# %% [markdown]
# mortality by difficulty cases-
# easy cases- ~1%- patients almost always survive
# medium difficulty- ~7% - still mostly survivors, but slightly harder
# difficult cases- ~83% - most patients die
# hardest cases- ~89% - extremely high risk patients that all models failed to detect correctly

# %%
#check overall mortality of validation set
val_results["label"].mean()
# Out:
# np.float64(0.13531967721911856)

# %% [markdown]
# perform multimodal difficulty test using LR, RF, XGBoost

# %%
#to understand extra cases captured as difficult by multi modal framework
val_results[val_results["num_models_wrong"] == 2]
# Out:
#       label  lr_pred  rf_pred  xgb_pred  lr_correct  rf_correct  xgb_correct  \
# 12        0        1        1         0       False       False         True
# 33        1        1        0         0        True       False        False
# 40        1        1        0         0        True       False        False
# 53        1        1        0         0        True       False        False
# 121       1        1        0         0        True       False        False
# ...     ...      ...      ...       ...         ...         ...          ...
# 3166      1        1        0         0        True       False        False
# 3176      0        1        0         1       False        True        False
# 3193      0        0        1         1        True       False        False
# 3203      1        1        0         0        True       False        False
# 3204      0        1        0         1       False        True        False
#
#       num_models_wrong difficulty
# 12                   2  difficult
# 33                   2  difficult
# 40                   2  difficult
# 53                   2  difficult
# 121                  2  difficult
# ...                ...        ...
# 3166                 2  difficult
# 3176                 2  difficult
# 3193                 2  difficult
# 3203                 2  difficult
# 3204                 2  difficult
#
# [220 rows x 9 columns]

# %%
#router predicts easy vs difficult
router_labels = (val_results["difficulty"] == "difficult").astype(int)

# %%
#train router
router = XGBClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.05,
    eval_metric="logloss"
)

router.fit(X_val, router_labels)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
#use router on training set
train_diff_probs = router.predict_proba(X_train)[:,1]

train_difficulty = (train_diff_probs >= 0.5).astype(int)

# %%
#split training data
X_easy = X_train[train_difficulty == 0]
y_easy = y_train[train_difficulty == 0]

X_difficult = X_train[train_difficulty == 1]
y_difficult = y_train[train_difficulty == 1]

print(X_easy.shape, X_difficult.shape)
# Out:
# (14506, 826) (175, 826)

# %%
#train specialized models
#easy model
easy_model = XGBClassifier(
    n_estimators=500,
    max_depth=5,
    learning_rate=0.05
)

easy_model.fit(X_easy, y_easy)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
#difficult model example
difficult_model = XGBClassifier(
    n_estimators=500,
    max_depth=7,
    learning_rate=0.03
)

difficult_model.fit(X_difficult, y_difficult)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
#router prediction
val_router_probs = router.predict_proba(X_val)[:,1]
val_router_pred = (val_router_probs >= 0.5).astype(int)

# %% [markdown]
# 0 - easy case
# 1 - difficult case

# %%
#split indices
#route to specialized model
import numpy as np

final_preds = np.zeros(len(X_val))

easy_idx = val_router_pred == 0
diff_idx = val_router_pred == 1

final_preds[easy_idx] = easy_model.predict_proba(X_val[easy_idx])[:,1]
final_preds[diff_idx] = difficult_model.predict_proba(X_val[diff_idx])[:,1]

# %%
#compute metrics
from sklearn.metrics import roc_auc_score, average_precision_score

roc = roc_auc_score(y_val, final_preds)
pr = average_precision_score(y_val, final_preds)

print("Routing Model ROC:", roc)
print("Routing Model PR :", pr)
# Out:
# Routing Model ROC: 0.9251442336189468
# Routing Model PR : 0.6927463371361822

# %%
#compare aginst single XGBoost
xgb_val_probs = model.predict_proba(X_val)[:,1]

from sklearn.metrics import roc_auc_score, average_precision_score

print("Baseline XGBoost ROC:", roc_auc_score(y_val, xgb_val_probs))
print("Baseline XGBoost PR :", average_precision_score(y_val, xgb_val_probs))
# Out:
# Baseline XGBoost ROC: 0.8638926941391097
# Baseline XGBoost PR : 0.5663751635113423

# %%
#number of easy and difficult cases from router split
print("Easy samples:", easy_idx.sum())
print("Difficult samples:", diff_idx.sum())
# Out:
# Easy samples: 2907
# Difficult samples: 315

# %%
#easy model performance
easy_roc = roc_auc_score(y_val[easy_idx],final_preds[easy_idx] )
easy_pr  = average_precision_score(y_val[easy_idx], final_preds[easy_idx])

print("Easy Model ROC:", easy_roc)
print("Easy Model PR :", easy_pr)
# Out:
# Easy Model ROC: 0.9165041892817621
# Easy Model PR : 0.7667960359063708

# %%
#difficult model performance
diff_roc = roc_auc_score(y_val[diff_idx], final_preds[diff_idx])
diff_pr  = average_precision_score(y_val[diff_idx], final_preds[diff_idx])

print("Difficult Model ROC:", diff_roc)
print("Difficult Model PR :", diff_pr)
# Out:
# Difficult Model ROC: 0.38516666666666666
# Difficult Model PR : 0.693975220013408

# %%
#compare to baseline xgboost model
baseline_easy_probs = model.predict_proba(X_val[easy_idx])[:,1]

print("Baseline Easy ROC:", roc_auc_score(y_val[easy_idx], baseline_easy_probs))

baseline_diff_probs = model.predict_proba(X_val[diff_idx])[:,1]

print("Baseline Difficult ROC:", roc_auc_score(y_val[diff_idx], baseline_diff_probs))
# Out:
# Baseline Easy ROC: 0.9226413176853184
# Baseline Difficult ROC: 0.04794444444444444

# %%
#feature importance by difficulty
easy_model.feature_importances_
difficult_model.feature_importances_
# Out:
# array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 7.5305048e-03, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.5431471e-03, 1.1157632e-03,
#        3.7862264e-04, 5.5452768e-04, 0.0000000e+00, 0.0000000e+00,
#        3.0337297e-04, 1.1620878e-03, 0.0000000e+00, 0.0000000e+00,
#        2.5502329e-03, 0.0000000e+00, 0.0000000e+00, 1.3442320e-03,
#        3.8730595e-03, 1.7910583e-03, 0.0000000e+00, 7.4717156e-03,
#        0.0000000e+00, 0.0000000e+00, 6.9996165e-03, 8.1948284e-03,
#        2.6910732e-04, 1.0267331e-03, 5.1891739e-03, 0.0000000e+00,
#        0.0000000e+00, 6.0895365e-03, 5.4882938e-04, 0.0000000e+00,
#        8.2856900e-04, 2.5672729e-03, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 1.3649905e-03, 0.0000000e+00, 8.8810525e-04,
#        6.8422440e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        7.5172856e-03, 2.9925383e-03, 1.0840032e-03, 2.4252100e-04,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.2056946e-02, 0.0000000e+00, 4.7430405e-03, 0.0000000e+00,
#        1.2311866e-02, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.4294676e-02, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.1059824e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 5.9299502e-03, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.0861394e-04,
#        5.0301929e-03, 2.8869193e-02, 0.0000000e+00, 3.5310835e-03,
#        8.1149135e-03, 0.0000000e+00, 6.6133431e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 3.3269036e-03, 2.7199453e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 8.7681403e-03, 0.0000000e+00,
#        3.8032184e-04, 3.1536391e-03, 0.0000000e+00, 0.0000000e+00,
#        5.4500005e-03, 0.0000000e+00, 0.0000000e+00, 4.1552326e-03,
#        1.3843980e-03, 0.0000000e+00, 0.0000000e+00, 5.4284371e-03,
#        9.5768459e-03, 0.0000000e+00, 0.0000000e+00, 9.1701694e-04,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.2660705e-02,
#        0.0000000e+00, 4.4660196e-03, 8.8051725e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.4893996e-03, 0.0000000e+00,
#        6.4505159e-04, 9.1168616e-04, 7.3588040e-04, 4.1667555e-04,
#        3.9115599e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.8115128e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 6.9972049e-03, 0.0000000e+00,
#        1.2501503e-03, 1.9521439e-03, 0.0000000e+00, 0.0000000e+00,
#        2.4881004e-03, 6.1209174e-04, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 9.1521731e-03, 0.0000000e+00,
#        0.0000000e+00, 2.2390923e-03, 0.0000000e+00, 7.5487612e-04,
#        0.0000000e+00, 6.1918254e-04, 4.1683558e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        2.4790317e-04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        3.1640851e-03, 0.0000000e+00, 1.2312796e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 3.7401477e-03, 2.0451869e-03, 0.0000000e+00,
#        0.0000000e+00, 4.0859501e-03, 0.0000000e+00, 0.0000000e+00,
#        4.1621709e-03, 2.7486782e-03, 0.0000000e+00, 0.0000000e+00,
#        3.6858008e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 1.3036766e-03, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 9.4247755e-04,
#        7.1175429e-03, 7.3613971e-03, 4.9515674e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 8.5508212e-04, 0.0000000e+00,
#        3.2109790e-04, 3.3086532e-04, 0.0000000e+00, 1.6676622e-03,
#        0.0000000e+00, 1.2056276e-03, 2.8149348e-03, 3.1093871e-03,
#        1.2010963e-03, 9.3804544e-04, 1.8621136e-03, 0.0000000e+00,
#        5.4045042e-05, 8.3240255e-04, 2.6103200e-03, 5.7408103e-04,
#        3.7567976e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        2.3277972e-03, 4.2736791e-03, 2.2622638e-03, 0.0000000e+00,
#        7.3736656e-04, 0.0000000e+00, 2.1219079e-04, 1.3337299e-03,
#        6.4505945e-04, 0.0000000e+00, 8.8518631e-04, 5.0291498e-03,
#        0.0000000e+00, 0.0000000e+00, 4.5165143e-04, 2.0435527e-03,
#        0.0000000e+00, 2.8589295e-04, 8.9601142e-04, 0.0000000e+00,
#        1.4321023e-02, 1.5903569e-03, 5.6590908e-03, 1.4131538e-03,
#        5.8995294e-03, 0.0000000e+00, 0.0000000e+00, 2.8511994e-03,
#        2.4152868e-03, 5.5415342e-03, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.7247975e-03, 3.4835744e-03,
#        8.0170913e-04, 4.9515162e-04, 3.0944664e-03, 0.0000000e+00,
#        0.0000000e+00, 1.8169663e-03, 1.5721300e-03, 8.8903395e-04,
#        9.2007255e-04, 2.8702097e-03, 0.0000000e+00, 0.0000000e+00,
#        1.0135850e-03, 2.1996899e-03, 1.0389262e-04, 2.8139323e-03,
#        3.3663267e-03, 0.0000000e+00, 0.0000000e+00, 2.3698846e-03,
#        1.9545027e-03, 0.0000000e+00, 2.1937275e-03, 2.5573021e-03,
#        0.0000000e+00, 0.0000000e+00, 1.5347624e-03, 4.0295030e-04,
#        1.2936867e-03, 6.9818244e-04, 4.4618994e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3356701e-02,
#        1.4303038e-03, 6.1192061e-04, 1.4090149e-02, 5.3382171e-03,
#        0.0000000e+00, 0.0000000e+00, 3.7044317e-03, 2.6444474e-03,
#        1.6743854e-03, 1.5194139e-03, 4.4620479e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.4289861e-03, 7.3867561e-03,
#        1.2655376e-03, 8.2331483e-04, 0.0000000e+00, 0.0000000e+00,
#        3.7125724e-03, 1.2286373e-03, 2.7140244e-03, 9.4657193e-04,
#        2.3676385e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0766571e-03, 0.0000000e+00, 2.5289124e-03, 1.7779998e-03,
#        0.0000000e+00, 0.0000000e+00, 8.5380283e-04, 6.2137470e-03,
#        5.3096083e-03, 0.0000000e+00, 3.4680442e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 4.9499114e-04, 0.0000000e+00,
#        0.0000000e+00, 5.0051520e-03, 0.0000000e+00, 0.0000000e+00,
#        8.3180057e-04, 1.2937606e-03, 4.1688920e-04, 5.2811247e-03,
#        4.5995865e-04, 6.0957563e-03, 0.0000000e+00, 1.6546421e-03,
#        3.8785604e-03, 0.0000000e+00, 2.4051047e-03, 7.1184238e-04,
#        0.0000000e+00, 0.0000000e+00, 6.8240578e-04, 6.8259449e-03,
#        0.0000000e+00, 0.0000000e+00, 1.9744101e-03, 0.0000000e+00,
#        0.0000000e+00, 6.3420995e-04, 1.3725718e-03, 0.0000000e+00,
#        2.2897702e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        3.0090190e-03, 2.7910979e-03, 2.6794446e-03, 0.0000000e+00,
#        4.1664545e-03, 0.0000000e+00, 0.0000000e+00, 3.9133453e-04,
#        1.1716137e-03, 3.4036435e-04, 0.0000000e+00, 3.5453974e-03,
#        0.0000000e+00, 0.0000000e+00, 9.2118280e-04, 6.5461255e-04,
#        9.1375997e-03, 4.2455268e-04, 3.5503265e-04, 0.0000000e+00,
#        0.0000000e+00, 5.1807989e-03, 1.6509055e-03, 6.1480417e-03,
#        3.2935701e-03, 6.9907011e-04, 0.0000000e+00, 0.0000000e+00,
#        5.2533853e-03, 2.8052302e-03, 0.0000000e+00, 0.0000000e+00,
#        4.7210618e-03, 1.0386774e-02, 0.0000000e+00, 1.7475351e-03,
#        6.1616208e-03, 0.0000000e+00, 1.9685633e-03, 5.0750189e-03,
#        0.0000000e+00, 0.0000000e+00, 3.9563314e-03, 5.2339905e-03,
#        1.1939553e-03, 9.7181997e-04, 1.9451155e-03, 0.0000000e+00,
#        0.0000000e+00, 2.6617716e-03, 2.7509606e-03, 1.7805474e-03,
#        0.0000000e+00, 4.3021402e-04, 0.0000000e+00, 0.0000000e+00,
#        3.6968867e-04, 0.0000000e+00, 1.2130613e-02, 3.0744821e-03,
#        9.4080158e-04, 0.0000000e+00, 0.0000000e+00, 2.1677888e-03,
#        1.8564884e-03, 0.0000000e+00, 9.4513013e-04, 3.1900699e-03,
#        0.0000000e+00, 0.0000000e+00, 4.8197128e-04, 2.8251510e-03,
#        7.9000654e-04, 0.0000000e+00, 6.5324816e-04, 0.0000000e+00,
#        0.0000000e+00, 5.5684811e-03, 5.6361910e-03, 1.0201492e-03,
#        1.1779545e-03, 2.5705143e-03, 0.0000000e+00, 0.0000000e+00,
#        2.7089245e-03, 1.6067651e-03, 9.5495200e-03, 1.5518167e-02,
#        3.6418673e-03, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        7.2362297e-04, 3.7301451e-03, 4.6648085e-03, 1.0887586e-03,
#        0.0000000e+00, 0.0000000e+00, 3.9466750e-03, 0.0000000e+00,
#        5.2948436e-04, 6.0554650e-03, 4.0112474e-04, 0.0000000e+00,
#        0.0000000e+00, 4.3199456e-04, 2.4101129e-03, 0.0000000e+00,
#        1.0047847e-02, 1.0885912e-02, 0.0000000e+00, 0.0000000e+00,
#        6.7405769e-04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        2.9449840e-04, 0.0000000e+00, 0.0000000e+00, 1.3933770e-03,
#        6.1455532e-04, 6.1489543e-04, 4.7010947e-03, 1.1288470e-03,
#        0.0000000e+00, 0.0000000e+00, 2.1812513e-03, 5.2905787e-04,
#        8.0195349e-04, 1.9734052e-03, 5.2039986e-03, 0.0000000e+00,
#        0.0000000e+00, 9.2665257e-04, 6.2579772e-04, 1.1819241e-03,
#        4.8278095e-03, 2.5439580e-04, 3.1468894e-03, 0.0000000e+00,
#        1.5900909e-03, 2.4074338e-04, 8.5694849e-04, 2.4733325e-03,
#        3.3473643e-03, 7.4170169e-04, 0.0000000e+00, 8.0488564e-04,
#        9.9449710e-04, 0.0000000e+00, 4.9130376e-03, 5.1407106e-03,
#        5.8741258e-03, 0.0000000e+00, 3.4326694e-03, 5.7754421e-04,
#        9.5356256e-04, 6.2304788e-04, 4.5605185e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.7230121e-03, 2.7493960e-03,
#        1.1870286e-03, 2.6551082e-03, 0.0000000e+00, 0.0000000e+00,
#        1.5916883e-03, 0.0000000e+00, 2.8603831e-03, 4.0663741e-04,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        8.3534070e-04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        2.3839052e-04, 0.0000000e+00, 2.6643625e-03, 4.5134835e-05,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 4.6272037e-04, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        4.9556233e-04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.4441049e-03,
#        5.9600559e-04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.2820715e-03, 0.0000000e+00, 0.0000000e+00, 2.7083901e-03,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 1.3500018e-02, 4.6168645e-03, 5.8629387e-03,
#        4.3191237e-04, 2.6994634e-03, 3.7039903e-03, 0.0000000e+00,
#        1.0485582e-03, 0.0000000e+00, 0.0000000e+00, 2.5107127e-03,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        4.6634749e-03, 1.0084219e-03, 1.4883499e-03, 1.9963640e-03,
#        6.5888744e-04, 0.0000000e+00, 1.0924460e-03, 2.8101457e-03,
#        2.1393728e-03, 1.7620202e-03, 3.0857043e-03, 2.7053553e-04,
#        0.0000000e+00, 2.5885999e-03, 4.3980698e-03, 0.0000000e+00,
#        0.0000000e+00, 6.4856769e-04, 1.1332303e-03, 0.0000000e+00,
#        1.6363794e-03, 1.9242964e-03, 0.0000000e+00, 4.4689728e-03,
#        0.0000000e+00, 1.5278350e-03, 0.0000000e+00, 3.1847411e-03,
#        1.5301232e-03, 3.4338070e-04, 1.5516228e-03, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00], dtype=float32)

# %%
#check how router split validation patients
np.bincount(val_router_pred)
# Out:
# array([2907,  315])

# %%
#check router accuracy
#tells us how well router identifies difficult patients
from sklearn.metrics import accuracy_score

print("Router Accuracy:", accuracy_score(router_labels, val_router_pred))
# Out:
# Router Accuracy: 0.9860335195530726

# %%
#evaluate routing system on test set to confirm generalization
test_router_probs = router.predict_proba(X_test)[:,1]
test_router_pred = (test_router_probs >= 0.5).astype(int)

final_test_preds = np.zeros(len(X_test))

easy_idx = test_router_pred == 0
diff_idx = test_router_pred == 1

final_test_preds[easy_idx] = easy_model.predict_proba(X_test[easy_idx])[:,1]
final_test_preds[diff_idx] = difficult_model.predict_proba(X_test[diff_idx])[:,1]

print("Routing Test ROC:", roc_auc_score(y_test, final_test_preds))
print("Routing Test PR :", average_precision_score(y_test, final_test_preds))
# Out:
# Routing Test ROC: 0.8592332873686924
# Routing Test PR : 0.5122530926415276

# %%
#evaluating easy and difficult specialized system on test set
print("Easy Test ROC:", roc_auc_score(y_test[easy_idx], final_test_preds[easy_idx]))
print("Easy Test PR :", average_precision_score(y_test[easy_idx], final_test_preds[easy_idx]))

print("Difficult Test ROC:", roc_auc_score(y_test[diff_idx], final_test_preds[diff_idx]))
print("Difficult Test PR :", average_precision_score(y_test[diff_idx], final_test_preds[diff_idx]))
# Out:
# Easy Test ROC: 0.8532763532763532
# Easy Test PR : 0.4836019911831893
# Difficult Test ROC: 0.6304347826086956
# Difficult Test PR : 0.8295122347737832

# %%
import pandas as pd

# Identify the columns that were skipped by the imputer (based on the UserWarning from d3jBAx2KEss-)
skipped_features = [
    'Height_full_skew', 'Height_first10_skew', 'Height_first25_skew',
    'Height_first50_skew', 'Height_last50_skew', 'Height_last25_skew',
    'Height_last10_skew'
]

# Filter feature_column_names to only include features that were not skipped
filtered_feature_column_names = [col for col in feature_column_names if col not in skipped_features]

easy_importance = pd.Series(
    easy_model.feature_importances_,
    index=filtered_feature_column_names
).sort_values(ascending=False)

diff_importance = pd.Series(
    difficult_model.feature_importances_,
    index=filtered_feature_column_names
).sort_values(ascending=False)

print("Top 10 features for Easy Model:")
print(easy_importance.head(10))
print("\nTop 10 features for Difficult Model:")
print(diff_importance.head(10))
# Out:
# Top 10 features for Easy Model:
# Glascow coma scale motor response_last25_max      0.091387
# Glascow coma scale motor response_last25_mean     0.047105
# Glascow coma scale verbal response_last25_max     0.032654
# Glascow coma scale motor response_last10_max      0.027614
# Glascow coma scale eye opening_last10_max         0.023418
# Glascow coma scale verbal response_last25_mean    0.019600
# Glascow coma scale verbal response_last10_min     0.017025
# Glascow coma scale eye opening_last10_mean        0.011613
# Glascow coma scale total_last50_max               0.010912
# Mean blood pressure_first10_count                 0.007892
# dtype: float32
#
# Top 10 features for Difficult Model:
# Glascow coma scale eye opening_full_min        0.028869
# Systolic blood pressure_first25_max            0.015518
# Heart Rate_full_mean                           0.014321
# Fraction inspired oxygen_first50_std           0.014295
# Mean blood pressure_full_max                   0.014090
# pH_full_mean                                   0.013500
# Mean blood pressure_full_mean                  0.013357
# Glascow coma scale eye opening_last25_count    0.012661
# Fraction inspired oxygen_first25_skew          0.012312
# Respiratory rate_last25_min                    0.012131
# dtype: float32

# %%
easy_importance.head(10)
diff_importance.head(10)
# Out:
# Glascow coma scale eye opening_full_min        0.028869
# Systolic blood pressure_first25_max            0.015518
# Heart Rate_full_mean                           0.014321
# Fraction inspired oxygen_first50_std           0.014295
# Mean blood pressure_full_max                   0.014090
# pH_full_mean                                   0.013500
# Mean blood pressure_full_mean                  0.013357
# Glascow coma scale eye opening_last25_count    0.012661
# Fraction inspired oxygen_first25_skew          0.012312
# Respiratory rate_last25_min                    0.012131
# dtype: float32

# %% [markdown]
# Add Isotonic Calibration and Threshold Tuning.
# ✔ Fit calibration ONLY on validation
# ✔ Apply to test (never refit)
# ✔ Tune threshold ONLY on validation
# ✔ Apply same threshold to test

# %%
#get validation predictions
val_probs = final_preds

# %%
#isotonic calibration
from sklearn.isotonic import IsotonicRegression

iso = IsotonicRegression(out_of_bounds="clip")

iso.fit(val_probs, y_val)
# Out:
# IsotonicRegression(out_of_bounds='clip')

# %%
#apply calibration
val_probs_cal = iso.transform(val_probs)

# %%
#quick check
import matplotlib.pyplot as plt

plt.scatter(val_probs, val_probs_cal, alpha=0.2)
plt.xlabel("Raw Probabilities")
plt.ylabel("Calibrated Probabilities")
plt.title("Isotonic Calibration Mapping")
plt.show()

# %%
#apply calibration to test
test_probs_cal = iso.transform(final_test_preds)

# %%
#pr-auc like behavior
import numpy as np
from sklearn.metrics import f1_score

thresholds = np.linspace(0.1, 0.9, 50)

best_thresh = 0
best_f1 = 0

for t in thresholds:
    preds = (val_probs_cal >= t).astype(int)
    f1 = f1_score(y_val, preds)

    if f1 > best_f1:
        best_f1 = f1
        best_thresh = t

print("Best Threshold:", best_thresh)
print("Best F1:", best_f1)
# Out:
# Best Threshold: 0.3448979591836735
# Best F1: 0.7256438969764838

# %%
#apply threshold on test
test_preds_final = (test_probs_cal >= best_thresh).astype(int)

# %%
#final evaluation
from sklearn.metrics import roc_auc_score, average_precision_score

print("Calibrated TEST ROC:", roc_auc_score(y_test, test_probs_cal))
print("Calibrated TEST PR :", average_precision_score(y_test, test_probs_cal))
# Out:
# Calibrated TEST ROC: 0.8567771686528624
# Calibrated TEST PR : 0.47228241803311516

# %%
#maximize precision given recall >= threshold
#so we can catch most high risk patients, but don't overwhelm with noise
from sklearn.metrics import precision_score, recall_score

thresholds = np.linspace(0.05, 0.9, 100)

best_thresh = 0
best_prec = 0

target_recall = 0.8  # try 0.75, 0.8, 0.85

for t in thresholds:
    preds = (val_probs_cal >= t).astype(int)

    recall = recall_score(y_val, preds)

    if recall >= target_recall:
        precision = precision_score(y_val, preds)

        if precision > best_prec:
            best_prec = precision
            best_thresh = t

print("Best Threshold:", best_thresh)
print("Precision:", best_prec)
# Out:
# Best Threshold: 0.1616161616161616
# Precision: 0.6190476190476191

# %% [markdown]
# catches 80% deaths but 38% flagged patients actually die. that means 62% false positives.
# false positive = extra monitoring
# false negative = missed critical patient

# %% [markdown]
# Add separate calibration on easy and difficult models

# %%
#fit easy and difficult model calibrators
iso_easy = IsotonicRegression(out_of_bounds="clip")
iso_diff = IsotonicRegression(out_of_bounds="clip")

# Re-compute easy_idx and diff_idx for validation set to avoid potential overwrites from test set logic
val_router_pred = (router.predict_proba(X_val)[:,1] >= 0.5).astype(int)
easy_idx_val = val_router_pred == 0
diff_idx_val = val_router_pred == 1

#fit separately
iso_easy.fit(final_preds[easy_idx_val], y_val[easy_idx_val])
iso_diff.fit(final_preds[diff_idx_val], y_val[diff_idx_val])
# Out:
# IsotonicRegression(out_of_bounds='clip')

# %%
#apply to test
# Re-calculate easy_idx and diff_idx for the test set using test_router_pred
easy_idx_test = (test_router_pred == 0)
diff_idx_test = (test_router_pred == 1)

easy_probs_test_cal = iso_easy.transform(final_test_preds[easy_idx_test])
diff_probs_test_cal = iso_diff.transform(final_test_preds[diff_idx_test])

# %%
#recombine
final_test_probs_cal = np.zeros(len(X_test))

final_test_probs_cal[easy_idx_test] = easy_probs_test_cal
final_test_probs_cal[diff_idx_test] = diff_probs_test_cal

# %%
#combined model evaluation
test_roc = roc_auc_score(y_test, final_test_probs_cal)
test_pr  = average_precision_score(y_test, final_test_probs_cal)

print("Separate Calibrated TEST ROC:", test_roc)
print("Separate Calibrated TEST PR :", test_pr)
# Out:
# Separate Calibrated TEST ROC: 0.8343848212050209
# Separate Calibrated TEST PR : 0.44183930436437246

# %%
#easy and difficult model evaluation after calibration
easy_test_roc = roc_auc_score(y_test[easy_idx_test], easy_probs_test_cal)
easy_test_pr  = average_precision_score(y_test[easy_idx_test], easy_probs_test_cal)

print("Easy Calibrated TEST ROC:", easy_test_roc)
print("Easy Calibrated TEST PR :", easy_test_pr)

diff_test_roc = roc_auc_score(y_test[diff_idx_test], diff_probs_test_cal)
diff_test_pr  = average_precision_score(y_test[diff_idx_test], diff_probs_test_cal)

print("Difficult Calibrated TEST ROC:", diff_test_roc)
print("Difficult Calibrated TEST PR :", diff_test_pr)
# Out:
# Easy Calibrated TEST ROC: 0.82641746376855
# Easy Calibrated TEST PR : 0.4169128894355243
# Difficult Calibrated TEST ROC: 0.5407608695652174
# Difficult Calibrated TEST PR : 0.7578952459254243

# %%
#threshold tuning after separate calibration
thresholds = np.linspace(0.05, 0.9, 100)

best_thresh = 0
best_prec = 0
target_recall = 0.8

for t in thresholds:
    preds = (final_test_probs_cal >= t).astype(int)
    recall = recall_score(y_test, preds)

    if recall >= target_recall:
        precision = precision_score(y_test, preds)
        if precision > best_prec:
            best_prec = precision
            best_thresh = t

print("Best Threshold:", best_thresh)
print("Precision:", best_prec)
# Out:
# Best Threshold: 0
# Precision: 0

# %% [markdown]
# # Task
# Initialize and fit an `IsotonicRegression` calibrator using the `xgb_val_probs` (probability predictions from the single XGBoost model on the validation dataset) and the true labels `y_val`. Then, apply this calibrator to the `test_probs` (probability predictions from the single XGBoost model on the test dataset) to obtain calibrated test probabilities. Finally, evaluate the performance of the calibrated XGBoost model on the test set using ROC-AUC and PR-AUC metrics, comparing them to the uncalibrated results.

# %% [markdown]
# ## Get XGBoost Validation Predictions
#
# ### Subtask:
# Obtain the probability predictions from the trained `model` (XGBoost) on the validation dataset (`X_val`). These will be used to fit the calibrator.

# %% [markdown]
# **Reasoning**:
# The subtask requires obtaining probability predictions from the trained XGBoost model on the validation dataset. The `predict_proba` method will return the probabilities for both classes, and we need to extract the probability of the positive class (index 1).

# %%
xgb_val_probs = model.predict_proba(X_val)[:,1]

# %% [markdown]
# # Task
# Initialize and fit an `IsotonicRegression` calibrator using the `xgb_val_probs` (probability predictions from the single XGBoost model on the validation dataset) and the true labels `y_val`. Then, apply this calibrator to the `test_probs` (probability predictions from the single XGBoost model on the test dataset) to obtain calibrated test probabilities. Finally, evaluate the performance of the calibrated XGBoost model on the test set using ROC-AUC and PR-AUC metrics, comparing them to the uncalibrated results.

# %% [markdown]
# ## Fit Isotonic Calibrator
#
# ### Subtask:
# Initialize and fit an `IsotonicRegression` calibrator using the `xgb_val_probs` (the previously obtained probability predictions from the single XGBoost model on the validation dataset) and the true labels `y_val`.

# %% [markdown]
# **Reasoning**:
# Initialize an `IsotonicRegression` calibrator with `out_of_bounds` set to 'clip' and fit it using the `xgb_val_probs` and `y_val`.

# %%
from sklearn.isotonic import IsotonicRegression

iso_single_xgb = IsotonicRegression(out_of_bounds="clip")
iso_single_xgb.fit(xgb_val_probs, y_val)
print("IsotonicRegression calibrator for single XGBoost fitted.")
# Out:
# IsotonicRegression calibrator for single XGBoost fitted.

# %% [markdown]
# **Reasoning**:
# Apply the fitted `IsotonicRegression` calibrator to the `test_probs` to obtain calibrated test probabilities for the single XGBoost model.

# %%
test_probs_cal_single_xgb = iso_single_xgb.transform(test_probs)
print("Test probabilities calibrated for single XGBoost.")
# Out:
# Test probabilities calibrated for single XGBoost.

# %% [markdown]
# **Reasoning**:
# To evaluate the performance of the calibrated single XGBoost model, calculate and print the ROC-AUC and PR-AUC scores using the calibrated test probabilities and true test labels.

# %%
from sklearn.metrics import roc_auc_score, average_precision_score

roc_cal_single_xgb = roc_auc_score(y_test, test_probs_cal_single_xgb)
pr_cal_single_xgb = average_precision_score(y_test, test_probs_cal_single_xgb)

print(f"Calibrated Single XGBoost Test ROC-AUC: {roc_cal_single_xgb:.4f}")
print(f"Calibrated Single XGBoost Test PR-AUC: {pr_cal_single_xgb:.4f}")
# Out:
# Calibrated Single XGBoost Test ROC-AUC: 0.8602
# Calibrated Single XGBoost Test PR-AUC: 0.4976

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the performance of the calibrated XGBoost model on the test set, highlighting any improvements or changes compared to the uncalibrated model.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The calibrated XGBoost model on the test set achieved a ROC-AUC of 0.8602 and a PR-AUC of 0.4976. This subtask focused on obtaining these calibrated metrics, and while it laid the groundwork for comparison, a direct comparison highlighting improvements or changes against the uncalibrated model was not explicitly performed in this step.
#
# ### Data Analysis Key Findings
# *   An `IsotonicRegression` calibrator was successfully initialized and fitted using the validation probabilities and true labels from the single XGBoost model.
# *   The calibrator was then applied to transform the uncalibrated test probabilities into calibrated test probabilities.
# *   The performance of the calibrated single XGBoost model on the test set was evaluated, yielding a ROC-AUC of 0.8602 and a PR-AUC of 0.4976.
#
# ### Insights or Next Steps
# *   Quantify the impact of isotonic calibration by comparing the current calibrated metrics (ROC-AUC: 0.8602, PR-AUC: 0.4976) directly against the previously obtained uncalibrated metrics for the single XGBoost model.
# *   Analyze the calibration curves of the uncalibrated and calibrated models to visually inspect the improvement in probability reliability.

# %% [markdown]
# # Task
# The current task is to summarize the performance of the calibrated XGBoost model and compare it to the uncalibrated model. To do this, I will:
# 1.  Recall the uncalibrated ROC-AUC and PR-AUC values for the single XGBoost model on the test set from previous execution.
# 2.  Compare these with the newly obtained calibrated ROC-AUC and PR-AUC values.
# 3.  Summarize the results and write them to a file.
# 4.  Move the results file to Google Drive.
#
# Here are the uncalibrated metrics for the single XGBoost model on the test set (from cell `M0AzCFe3HAFl`):
# *   Uncalibrated Single XGBoost Test ROC-AUC: 0.8630
# *   Uncalibrated Single XGBoost Test PR-AUC: 0.5224
#
# And the calibrated metrics (from cell `90017010`):
# *   Calibrated Single XGBoost Test ROC-AUC: 0.8602
# *   Calibrated Single XGBoost Test PR-AUC: 0.4976
#
# Let's now compare these and generate the summary.
#
# ```python
# # Recall uncalibrated metrics (from cell M0AzCFe3HAFl output)
# uncalibrated_roc_single_xgb = 0.8630206990362373
# uncalibrated_pr_single_xgb = 0.5224254465486005
#
# # Calibrated metrics (from current execution, variables roc_cal_single_xgb, pr_cal_single_xgb)
# # roc_cal_single_xgb = 0.8602151743106239
# # pr_cal_single_xgb = 0.49763657914301385
#
# summary = f"""
# Performance Summary for Single XGBoost Model (Test Set):
#
# Uncalibrated Model:
#   ROC-AUC: {uncalibrated_roc_single_xgb:.4f}
#   PR-AUC:  {uncalibrated_pr_single_xgb:.4f}
#
# Calibrated Model (Isotonic Regression):
#   ROC-AUC: {roc_cal_single_xgb:.4f}
#   PR-AUC:  {pr_cal_single_xgb:.4f}
#
# Comparison:
# After applying Isotonic Regression calibration, the ROC-AUC slightly decreased from {uncalibrated_roc_single_xgb:.4f} to {roc_cal_single_xgb:.4f}.
# The PR-AUC also slightly decreased from {uncalibrated_pr_single_xgb:.4f} to {pr_cal_single_xgb:.4f}.
#
# This suggests that while calibration aims to improve the reliability of probability estimates, it does not always lead to improvements in discrimination metrics like ROC-AUC and PR-AUC. The primary goal of isotonic regression is to correct for miscalibration (i.e., when predicted probabilities do not match true event frequencies), rather than directly optimizing for discriminative power.
# """
#
# print(summary)
#
# # Save the summary to a file
# with open("single_xgb_calibrated_results.txt", "w") as f:
#     f.write(summary)
#
# # Move the results file to Google Drive
# !mv single_xgb_calibrated_results.txt /content/drive/MyDrive/
#
# print("\nSummary saved to /content/drive/MyDrive/single_xgb_calibrated_results.txt")
# ```

# %% [markdown]
# ## Apply Calibrator to Test Predictions
#
# ### Subtask:
# Apply the fitted `IsotonicRegression` calibrator (iso_single_xgb) to the `test_probs` (probability predictions from the single XGBoost model on the test dataset) to obtain calibrated test probabilities.

# %% [markdown]
# **Reasoning**:
# Apply the fitted `IsotonicRegression` calibrator to the `test_probs` to obtain calibrated test probabilities for the single XGBoost model.

# %%
test_probs_cal_single_xgb = iso_single_xgb.transform(test_probs)
print("Test probabilities calibrated for single XGBoost.")
# Out:
# Test probabilities calibrated for single XGBoost.

# %% [markdown]
# **Reasoning**:
# The previous step successfully calibrated the test probabilities. Now, I need to execute the final part of the task which is to compare the calibrated and uncalibrated metrics, summarize them, save the summary to a file, and move it to Google Drive.

# %%
uncalibrated_roc_single_xgb = 0.8630206990362373
uncalibrated_pr_single_xgb = 0.5224254465486005

# calibrated metrics (from current execution, variables roc_cal_single_xgb, pr_cal_single_xgb)
# roc_cal_single_xgb = 0.8602151743106239
# pr_cal_single_xgb = 0.49763657914301385

summary = f"""
Performance Summary for Single XGBoost Model (Test Set):

Uncalibrated Model:
  ROC-AUC: {uncalibrated_roc_single_xgb:.4f}
  PR-AUC:  {uncalibrated_pr_single_xgb:.4f}

Calibrated Model (Isotonic Regression):
  ROC-AUC: {roc_cal_single_xgb:.4f}
  PR-AUC:  {pr_cal_single_xgb:.4f}

Comparison:
After applying Isotonic Regression calibration, the ROC-AUC slightly decreased from {uncalibrated_roc_single_xgb:.4f} to {roc_cal_single_xgb:.4f}.
The PR-AUC also slightly decreased from {uncalibrated_pr_single_xgb:.4f} to {pr_cal_single_xgb:.4f}.

This suggests that while calibration aims to improve the reliability of probability estimates, it does not always lead to improvements in discrimination metrics like ROC-AUC and PR-AUC. The primary goal of isotonic regression is to correct for miscalibration (i.e., when predicted probabilities do not match true event frequencies), rather than directly optimizing for discriminative power.
"""

print(summary)

# Save the summary to a file
with open("single_xgb_calibrated_results.txt", "w") as f:
    f.write(summary)

# Move the results file to Google Drive
get_ipython().system('mv single_xgb_calibrated_results.txt /content/drive/MyDrive/')

print("\nSummary saved to /content/drive/MyDrive/single_xgb_calibrated_results.txt")
# Out:
# Performance Summary for Single XGBoost Model (Test Set):
#
# Uncalibrated Model:
#   ROC-AUC: 0.8630
#   PR-AUC:  0.5224
#
# Calibrated Model (Isotonic Regression):
#   ROC-AUC: 0.8602
#   PR-AUC:  0.4976
#
# Comparison:
# After applying Isotonic Regression calibration, the ROC-AUC slightly decreased from 0.8630 to 0.8602.
# The PR-AUC also slightly decreased from 0.5224 to 0.4976.
#
# This suggests that while calibration aims to improve the reliability of probability estimates, it does not always lead to improvements in discrimination metrics like ROC-AUC and PR-AUC. The primary goal of isotonic regression is to correct for miscalibration (i.e., when predicted probabilities do not match true event frequencies), rather than directly optimizing for discriminative power.
#
#
# Summary saved to /content/drive/MyDrive/single_xgb_calibrated_results.txt

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The performance of the calibrated XGBoost model on the test set, compared to the uncalibrated model, shows a slight decrease in both ROC-AUC and PR-AUC. The calibrated model yielded an ROC-AUC of 0.8602 and a PR-AUC of 0.4976, while the uncalibrated model had an ROC-AUC of 0.8630 and a PR-AUC of 0.5224.
#
# ### Data Analysis Key Findings
# *   The uncalibrated single XGBoost model achieved a ROC-AUC of 0.8630 and a PR-AUC of 0.5224 on the test set.
# *   After applying Isotonic Regression calibration, the ROC-AUC for the single XGBoost model on the test set slightly decreased from 0.8630 to 0.8602.
# *   Similarly, the PR-AUC for the single XGBoost model on the test set slightly decreased from 0.5224 to 0.4976 after calibration.
#
# ### Insights or Next Steps
# *   Isotonic Regression calibration, while intended to improve the reliability of probability estimates, does not guarantee an improvement in discriminative metrics like ROC-AUC or PR-AUC. Its primary goal is to correct miscalibration rather than optimize discriminative power.
# *   Further investigation could involve evaluating calibration plots (e.g., reliability diagrams) to confirm if the calibration process indeed improved the accuracy of the predicted probabilities, despite the slight drop in discrimination metrics.
